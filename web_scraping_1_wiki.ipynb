# %%
import requests

# %%
#specify the url we want to scrape from
Link = "https://en.wikipedia.org/wiki/List_of_autobiographies_by_Indians"
#convert the web page to text
Link_text = requests.get(Link).text
print(Link_text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of autobiographies by Indians - Wikipedia</title>
# ...

# %%
#import BautifulSoup library to pull data out of HTML and XML files
from bs4 import BeautifulSoup
#to convert Link_text into a BeautifulSoup Object
soup = BeautifulSoup(Link_text, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of autobiographies by Indians - Wikipedia</title>
# ...

# %%
#make the indentation proper
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of autobiographies by Indians - Wikipedia
#   </title>
#   <script>
# ...

# %%
#To take a look at the title of the web page
print(soup.title)
# Out:
# <title>List of autobiographies by Indians - Wikipedia</title>

# %%
#Only the string not the tags
print(soup.title.string)
# Out:
# List of autobiographies by Indians - Wikipedia

# %%
#First <a></a> tag
soup.a
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
#all the <a> </a> tags
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
#Fetch all the table tags
all_table = soup.find_all('table')
print(all_table)
# Out:
# [<table class='wikitable sortable sortable"'>
# <tbody><tr>
# <th>Author</th>
# <th>Title of book</th>
# <th>Year</th>
# <th>Remarks
# </th></tr>
# <tr>
# <td><a href="/wiki/Valmiki" title="Valmiki">Valmiki</a></td>
# <td><i><a href="/wiki/Ramayana" title="Ramayana">Ramayana</a></i></td>
# <td>500 BCE to 100 BCE</td>
# <td>Sanskrit
# </td></tr>
# <tr>
# <td><a href="/wiki/Banarasidas" title="Banarasidas">Banarasidas</a></td>
# <td><i>Ardhakathānaka</i></td>
# <td>1641</td>
# <td>Braj Bhasha
# </td></tr>
# <tr>
# <td><a href="/wiki/Rassundari_Devi" title="Rassundari Devi">Rassundari Devi</a></td>
# <td><i><a href="/wiki/Aamar_Jiban" title="Aamar Jiban">Aamar Jiban</a></i></td>
# <td>1876</td>
# <td>Bengali
# </td></tr>
# <tr>
# <td><a href="/wiki/Bhagat_Singh" title="Bhagat Singh">Bhagat Singh</a></td>
# <td><i>Why I Am An Atheist</i></td>
# <td>1931</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Narmad" title="Narmad">Narmad</a></td>
# ...

# %%
#fetch all the table tags with class name="wikitable sortable"
our_table = soup.find('table', class_= 'wikitable sortable sortable"')
print(our_table)
# Out:
# <table class='wikitable sortable sortable"'>
# <tbody><tr>
# <th>Author</th>
# <th>Title of book</th>
# <th>Year</th>
# <th>Remarks
# </th></tr>
# <tr>
# <td><a href="/wiki/Valmiki" title="Valmiki">Valmiki</a></td>
# <td><i><a href="/wiki/Ramayana" title="Ramayana">Ramayana</a></i></td>
# <td>500 BCE to 100 BCE</td>
# <td>Sanskrit
# </td></tr>
# <tr>
# <td><a href="/wiki/Banarasidas" title="Banarasidas">Banarasidas</a></td>
# <td><i>Ardhakathānaka</i></td>
# <td>1641</td>
# <td>Braj Bhasha
# </td></tr>
# <tr>
# <td><a href="/wiki/Rassundari_Devi" title="Rassundari Devi">Rassundari Devi</a></td>
# <td><i><a href="/wiki/Aamar_Jiban" title="Aamar Jiban">Aamar Jiban</a></i></td>
# <td>1876</td>
# <td>Bengali
# </td></tr>
# <tr>
# <td><a href="/wiki/Bhagat_Singh" title="Bhagat Singh">Bhagat Singh</a></td>
# <td><i>Why I Am An Atheist</i></td>
# <td>1931</td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Narmad" title="Narmad">Narmad</a></td>
# ...

# %%
#In the table that we will fetch find the <a> </a>tags  
table_links = our_table.find_all('a')
print(table_links)
# Out:
# [<a href="/wiki/Valmiki" title="Valmiki">Valmiki</a>, <a href="/wiki/Ramayana" title="Ramayana">Ramayana</a>, <a href="/wiki/Banarasidas" title="Banarasidas">Banarasidas</a>, <a href="/wiki/Rassundari_Devi" title="Rassundari Devi">Rassundari Devi</a>, <a href="/wiki/Aamar_Jiban" title="Aamar Jiban">Aamar Jiban</a>, <a href="/wiki/Bhagat_Singh" title="Bhagat Singh">Bhagat Singh</a>, <a href="/wiki/Narmad" title="Narmad">Narmad</a>, <a href="/wiki/Mari_Hakikat" title="Mari Hakikat">Mari Hakikat</a>, <a href="/wiki/B._R._Ambedkar" title="B. R. Ambedkar">B. R. Ambedkar</a>, <a href="/wiki/Waiting_for_a_Visa" title="Waiting for a Visa">Waiting for a Visa</a>, <a href="/wiki/Columbia_University" title="Columbia University">Columbia University</a>, <a href="#cite_note-1">[1]</a>, <a href="/wiki/Jawaharlal_Nehru" title="Jawaharlal Nehru">Jawaharlal Nehru</a>, <a href="/wiki/An_Autobiography_(Nehru)" title="An Autobiography (Nehru)">An Autobiography</a>, <a class="mw-redirect" href="/wiki/Moh
# ...

# %%
#put the title into a list 
autobiographies = []
for links in table_links:
    autobiographies.append(links.get('title'))
print(autobiographies)
# Out:
# ['Valmiki', 'Ramayana', 'Banarasidas', 'Rassundari Devi', 'Aamar Jiban', 'Bhagat Singh', 'Narmad', 'Mari Hakikat', 'B. R. Ambedkar', 'Waiting for a Visa', 'Columbia University', None, 'Jawaharlal Nehru', 'An Autobiography (Nehru)', 'Mohandas Karamchand Gandhi', 'The Story of My Experiments with Truth', 'Vikram Sampath', 'Savarkar: Echoes from a Fogotten Past 1883-1924 (Part 1) (page does not exist)', 'Vikram Sampath', 'Savarkar: A Contested Legacy 1924-1966 (page does not exist)', 'Paramahansa Yogananda', None, 'Rajendra Prasad', 'U. V. Swaminatha Iyer', 'Nirad C. Chaudhuri', 'The Autobiography of an Unknown Indian', 'Prakash Tandon', 'Ravi Shankar', 'Kamala Surayya', 'Ente Katha', 'My Story (Das book)', 'Anna Chandy', 'Swami Rama', 'Manilal Dwivedi', 'Atmavrittanta', 'Dhirubhai Thaker', 'Sita Ram Goel', 'How I Became a Hindu', 'Satyajit Ray', 'Jakhan Choto Chilam', 'Shantabai Kamble', 'Majya Jalmachi Chittarkatha', 'Dalit', 'A. P. J. Abdul Kalam', 'Wings of Fire (autobiography)', 'K
# ...

# %%
#Convert the list into a dataframe 
import pandas as pd
df_auto = pd.DataFrame(autobiographies)
print(df_auto)
# Out:
#                                0
# 0                        Valmiki
# 1                       Ramayana
# 2                    Banarasidas
# 3                Rassundari Devi
# 4                    Aamar Jiban
# ..                           ...
# 98                  Urmila Pawar
# 99                Babytai Kamble
# 100              Narendra Jadhav
# 101             Shantabai Kamble
# 102  Majya Jalmachi Chittarkatha
#
# [103 rows x 1 columns]

# %%
pip install xlsxwriter
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting xlsxwriter
# ...
#      -------------------------------------- 154.8/154.8 kB 1.5 MB/s eta 0:00:00
# ...

# %%
#To save the data into an excel file 
writer = pd.ExcelWriter('indian_autobiographies.xlsx', engine='xlsxwriter')
df_auto.to_excel(writer, sheet_name='List')
writer.save()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5372\2123105098.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
#check if it’s done right or not
df1= pd.read_excel('indian_autobiographies.xlsx')
df1
# Out:
#      Unnamed: 0                            0
# 0             0                      Valmiki
# 1             1                     Ramayana
# 2             2                  Banarasidas
# 3             3              Rassundari Devi
# 4             4                  Aamar Jiban
# ..          ...                          ...
# 98           98                 Urmila Pawar
# 99           99               Babytai Kamble
# 100         100              Narendra Jadhav
# 101         101             Shantabai Kamble
# 102         102  Majya Jalmachi Chittarkatha
#
# [103 rows x 2 columns]
